# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

# Ruta a la carpeta con imágenes
train_dir = Path('train')

image_paths = sorted(train_dir.glob('*.jpg'))

for path in image_paths[:6]:
    img = Image.open(path)
    plt.imshow(img)
    plt.title(path.name)
    plt.axis('off')
    plt.show()

# %%
import pandas as pd
import numpy as np

# Leyendo la plantilla de envío
sub = pd.read_csv('sample_submission.csv')
print('✔️ sample_submission.csv leído. Tamaño:', sub.shape)

sub.head()
# Out:
# ✔️ sample_submission.csv leído. Tamaño: (24, 2)
#     test_image_path  class
# 0  test/image_0.jpg      0
# 1  test/image_1.jpg      0
# 2  test/image_2.jpg      0
# 3  test/image_4.jpg      0
# 4  test/image_5.jpg      0

# %%
random_values = np.random.randint(0, 6, size=sub.iloc[:, 1:].shape)
sub.iloc[:, 1:] = random_values

sub.to_csv('submission.csv', index=False)
print('submission.csv Guardado - se puede enviar o descargar.')
# Out:
# submission.csv Guardado - se puede enviar o descargar.
